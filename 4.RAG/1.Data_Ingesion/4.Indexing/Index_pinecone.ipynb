# %%
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader("data/chase_banking.pdf")

documents=loader.load()

print(documents)

# %%
import pinecone

# Install the Pinecone client library (uncomment if not installed)
# !pip install pinecone-client

# Initialize the Pinecone client
pinecone.init(api_key='your-api-key')

# %%
import os
from dotenv import load_dotenv

load_dotenv()

pinecone_key = os.getenv('PINECONE_APIKEY')
print(pinecone_key)

# %%
import pinecone

# Install the Pinecone client library (uncomment if not installed)
# !pip install pinecone-client

# Initialize the Pinecone client
#pinecone_client = pinecone.Client(api_key=pinecone_key)
pinecone.init(api_key=pinecone_key)

# %%
import pinecone

pinecone.init(api_key=pinecone_key)

# %%
from pinecone.grpc import PineconeGRPC as Pinecone

pc = Pinecone(api_key=pinecone_key)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pinecone.grpc import PineconeGRPC as Pinecone
#       3 pc = Pinecone(api_key=pinecone_key)
#
# File ~/IAI/AgenticGenerativeAI/Week7/lab2/.venv/lib/python3.12/site-packages/pinecone/grpc/__init__.py:47
#       1 """
#       2 Connecting to Pinecone with GRPC
#       3
#    (...)     44
#      45 """
# ---> 47 from .index_grpc import GRPCIndex
#      48 from .pinecone import PineconeGRPC
#      49 from .config import GRPCClientConfig
#
# File ~/IAI/AgenticGenerativeAI/Week7/lab2/.venv/lib/python3.12/site-packages/pinecone/grpc/index_grpc.py:4
#       1 import logging
#       2 from typing import Optional, Dict, Union, List, Tuple, Any, Iterable, cast, Literal
# ----> 4 from google.protobuf import json_format
#       6 from pinecone.utils.tqdm import tqdm
# ...
