# %%
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader("data/chase_banking.pdf")

documents=loader.load()

print(documents)
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 19.5 (Macintosh)', 'creationdate': '2024-10-03T09:29:06-04:00', 'author': 'JPMorgan Chase Bank', 'keywords': 'Chase; total; checking; guide to your account; ada; (PDF)', 'moddate': '2024-10-07T09:59:35-04:00', 'subject': 'Chase Total Checking - A Guide To Your Account', 'title': 'Chase Total Checking - A Guide To Your Account (PDF)', 'trapped': '/Unknown', 'source': 'data/chase_banking.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content='HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT\n1\nCHASE TOTAL CHECKING\n®\nA GUIDE TO YOUR ACCOUNT †\nIt’s important that you understand how your Chase Total Checking account works. \nWe’ve created this Guide to explain the fees and some key terms of your personal account.\nMONTHLY \nSERVICE FEE*\nMonthly Service Fee $12\nWays to Avoid the \nMonthly Service Fee\n$0 Monthly Service Fee when you have any ONE  of the following during each \nmonthly statement period:\n•  Electronic deposits made into this account totaling $500 or more, such as \npayments from payroll providers or government benefit providers, by using \n(i) the ACH network, (ii) the Real Time Payment or FedNow SM network, or  \n(ii\ni) third party services that facilitate payments to your debit card using the \nVisa® or Mastercard® network\n• OR, a balance at the beginning of each day of $1,500 or more in this account\n•  OR, an average beginning day balance of $5,000 or more in any combination \nof this account and linked qualifying deposits 1/investments 2\nATM FEES\nNon-Chase ATM \n(Avoid these fees by \nusing a Chase ATM)\n$3 per withdrawal at a non-Chase ATM in the U.S. and the U.S. territories\n$5 per withdrawal at a non-Chase ATM outside the U.S. and the U.S. territories\nSurcharge Fees from the ATM owner/network still apply. U.S. territories include \nAmerican Samoa, Guam, the Northern Mariana Islands, Puerto Rico, and the \nU.S. Virgin Islands\nFees for using your account when you don’t have enough money in it or it’s already overdrawn\nOVERDRAFT FEES\nOverdraft:\nChase pays a \ntransaction \nduring our nightly \nprocessing \non a business \nday when your \naccount balance is \noverdrawn\n$34 Overdraft Fee per transaction during our nightly processing beginning with \nthe first transaction that overdraws your account balance by more than $50.\n• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:\n•  With Chase Overdraft Assist SM, if you’re overdrawn by $50 or less at the \nend of the business day OR if you’re overdrawn by more than $50 and you \nbring your account balance to overdrawn by $50 or less at the end of the \nnext business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit \nor transfer). Chase Overdraft Assist does not require enrollment and comes \nwith eligible Chase checking accounts\n• If your transaction is $5 or less\n•  If your debit card transaction was authorized when there was a sufficient \navailable balance in your account\n•  If your check or ACH is returned unpaid. However, we may charge an Overdraft \nFee if a previously returned check or ACH is presented again and paid\n• If your debit card transaction or ATM cash withdrawal request is declined\nYou can avoid overdrawing your account by making a deposit or transferring funds to cover the overdraft before the \nbusiness day ends and we start our nightly processing. Here are the cutoff times for some ways of making a deposit or \ntransferring funds from another Chase account:\n• At a branch before it closes\n• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)\n• When transferring money on chase.com  or Chase Mobile® or using Zelle® before 11 p.m. Eastern Time (8 p.m. Pacific Time)\nIf you deposit a check, this assumes we do not place a hold and the check is not returned. Additional cutoff times apply to \nother tra ...

# %% [markdown]
# #### Charactre Text Splitter

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter=CharacterTextSplitter(
    
    separator="",
    chunk_size=100,
    chunk_overlap=20
)

# %%
chunks=[]

for doc in documents:
    
    texts=text_splitter.split_text(doc.page_content)
    chunks.extend(texts)

# %%
for chunk in enumerate(chunks):
    print(chunk)
# Out:
# (0, 'HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE T')
# (1, 'NT MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT\n1\nCHASE TOTAL CHECKING\n®\nA GUIDE TO YOUR ACCOUNT †')
# (2, 'E TO YOUR ACCOUNT †\nIt’s important that you understand how your Chase Total Checking account works.')
# (3, 'king account works. \nWe’ve created this Guide to explain the fees and some key terms of your persona')
# (4, 'erms of your personal account.\nMONTHLY \nSERVICE FEE*\nMonthly Service Fee $12\nWays to Avoid the \nMont')
# (5, 's to Avoid the \nMonthly Service Fee\n$0 Monthly Service Fee when you have any ONE  of the following d')
# (6, 'of the following during each \nmonthly statement period:\n•  Electronic deposits made into this acco')
# (7, 'made into this account totaling $500 or more, such as \npayments from payroll providers or governmen')
# (8, 'oviders or government benefit providers, by using \n(i) the ACH network, (ii) the Real Time Payment o')
# (9, 'Real Time Payment or FedNow SM network, or  \n(ii\ni) third party services that facilitate payments t')
# (10, 'acilitate payments to your debit card using the \nVisa® or Mastercard® network\n• OR, a balance at the')
# (11, 'OR, a balance at the beginning of each day of $1,500 or more in this account\n•  OR, an average begin')
# (12, 'OR, an average beginning day balance of $5,000 or more in any combination \nof this account and linke')
# (13, 'is account and linked qualifying deposits 1/investments 2\nATM FEES\nNon-Chase ATM \n(Avoid these fees')
# (14, '(Avoid these fees by \nusing a Chase ATM)\n$3 per withdrawal at a non-Chase ATM in the U.S. and the')
# (15, 'in the U.S. and the U.S. territories\n$5 per withdrawal at a non-Chase ATM outside the U.S. and the U')
# (16, 'e the U.S. and the U.S. territories\nSurcharge Fees from the ATM owner/network still apply. U.S. terr')
# (17, 'ill apply. U.S. territories include \nAmerican Samoa, Guam, the Northern Mariana Islands, Puerto Rico')
# (18, 'Islands, Puerto Rico, and the \nU.S. Virgin Islands\nFees for using your account when you don’t have e')
# (19, 'hen you don’t have enough money in it or it’s already overdrawn\nOVERDRAFT FEES\nOverdraft:\nChase pays')
# (20, 'verdraft:\nChase pays a \ntransaction \nduring our nightly \nprocessing \non a business \nday when your \na')
# (21, 'ss \nday when your \naccount balance is \noverdrawn\n$34 Overdraft Fee per transaction during our nightl')
# (22, 'on during our nightly processing beginning with \nthe first transaction that overdraws your account b')
# (23, 'draws your account balance by more than $50.\n• Maximum of 3 fees per business day (up to $102)\nWe wo')
# (24, 'y (up to $102)\nWe won’t charge an Overdraft Fee:\n•  With Chase Overdraft Assist SM, if you’re overdr')
# (25, 'SM, if you’re overdrawn by $50 or less at the \nend of the business day OR if you’re overdrawn by mor')
# (26, '’re overdrawn by more than $50 and you \nbring your account balance to overdrawn by $50 or less at th')
# (27, 'by $50 or less at the end of the \nnext business day (you have until 11 p.m. ET (8 p.m. PT) to make a')
# (28, '8 p.m. PT) to make a deposit \nor transfer). Chase Overdraft Assist does not require enrollment and c')
# (29, 'ire enrollment and comes \nwith eligible Chase checking accounts\n• If your transaction is $5 or less')
# (30, 'ction is $5 or less\n•  If your debit card transaction was authorized when there was a sufficient \nav')
# (31, 'was a sufficient \navailable balance in your account\n•  If your check or ACH is returned unpaid. Howe')
# (32, 'eturned unpaid. However, we may charge an Overdraft \nFee if a previously returned check or ACH is pr')
# (33, 'd check or ACH is presented again and paid\n• If your debit card transaction or ATM cash withdrawal r')
# (34, 'TM cash withdrawal request is declined\nYou can avoid overdrawing your account by making a deposit or')
# (35, 'making a deposit or transferring funds to cover the overdraft before the \nbusiness day ends and we')
# (36, 'ess day ends and we start our nightly processing. Here are the cutoff times for some ways of making')
# (37, 'some ways of making a deposit or \ntransferring funds from another Chase account:\n• At a branch befor')
# (38, '• At a branch before it closes\n• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)\n• When')
# (39, 'Pacific Time)\n• When transferring money on chase.com  or Chase Mobile® or using Zelle® before 11 p.m')
# (40, 'Zelle® before 11 p.m. Eastern Time (8 p.m. Pacific Time)\nIf you deposit a check, this assumes we do')
# (41, 'this assumes we do not place a hold and the check is not returned. Additional cutoff times apply to')
# (42, 'utoff times apply to \nother transfers, including transfers from non-Chase accounts. Please visit cha')
# (43, 'ts. Please visit chase.com or Chase Mobile for more information \nand service agreements.\n†  For the')
# (44, 'eements.\n†  For the complete terms governing your account, please consult the Deposit Account Agreem')
# (45, 'posit Account Agreement . The terms of the account, including any fees or features, may change.\n*')
# (46, 'es, may change.\n*\t \tNew\tand\tconverted\tacco unts\twill\tnot\tbe\tchar ged\ta\tMonth ly\tServi ce\tFee\tfor\tat')
# (47, 'Servi ce\tFee\tfor\tat\tleas t\tthe\tfirst\ttwo\tstat ement\tperi ods.\tAfte r\tthat\tthe\tMont hly\tServi ce\tFee')
# (48, 'nt hly\tServi ce\tFee\twill\tappl y\tunles s\tyou\tmeet\tone\tof\tthe\tways\tto\tavoi d\tthe\tMont hly\tServi ce\t\nFe')
# (49, 'ont hly\tServi ce\t\nFee each statement period (if applicable).\n1   Qualifying personal deposits includ')
# (50, 'onal deposits include Chase First Checking SM accounts, personal Chase savings accounts (excluding C')
# (51, 'ccounts (excluding Chase Premier Savings SM and Chase Private Client Savings SM), CDs, certain Chase')
# (52, ', CDs, certain Chase Retirement CDs, and certain \nChase Retirement Money Market Accounts.\n2\t \tQualif')
# (53, 'Accounts.\n2\t \tQualifying\tperso nal\tinvest ments\tinclude\tbalanc es\tin\tinvest ment\tand\tannuity\tproduc')
# (54, 'and\tannuity\tproduc ts\toffered\tthroug h\tJPMor gan\tChase\t&\tCo.\tand\tits\taffiliate s\tand\tagenci es.\tFor')
# (55, 's\tand\tagenci es.\tFor\tmost\tproduc ts,\twe\tuse\tdaily\tbalanc es\tto\tcalcu late\tthe\t\naverage beginning day')
# (56, 'verage beginning day balance for such investment and annuity products. Some third party providers re')
# (57, 'd party providers report balances on a weekly, not daily, basis and we will use the most current bal')
# (58, 'the most current balance reported. Balances in 529 plans,  \ndon\nor-advised funds, and certain retire')
# (59, ', and certain retirement plan investment accounts do not qualify. Investment products and related se')
# (60, 'ducts and related services are only available in English.\n\t J.P.\tMorgan\tWeal th\tMana gement\tis\ta\tbus')
# (61, 'Mana gement\tis\ta\tbusi ness\tof\tJPMo rgan\tChas e\t&\tCo.,\twhic h\toffer s\tinve stment\tprod ucts\tand\tservi')
# (62, 'prod ucts\tand\tservi ces\tthro ugh\tJ.P. Morgan Securities LLC\t(JPMS),\ta\tregistered\tbrok er-dealer\tand')
# (63, 'd\tbrok er-dealer\tand\tinve stment\tadvise r,\t\nmember FINRA and SIPC. Insurance products are made avail')
# (64, 'ducts are made available through Chase Insurance Agency, Inc. (CIA), a licensed insurance agency, do')
# (65, 'insurance agency, doing business as Chase Insurance Agency Services, Inc. in Florida. Certain custod')
# (66, 'rida. Certain custody \nand\tother\tservices\tare\tprovided\tby\tJPMorgan\tChase\tBank,\tN.A.\t(JPMCB).\tJPMS,\tC')
# (67, '.A.\t(JPMCB).\tJPMS,\tCIA\tand\tJPMCB\tare\taffiliated\tcompanies\tunder\tthe\tcommon\tcontrol\tof\tJPMorgan\tChase')
# (68, 'ol\tof\tJPMorgan\tChase\t&\tCo.\tProducts\tnot\tavailable\tin\tall\tstates.\nINVESTMENT AND INSURANCE PRODUCTS:')
# (69, 'INSURANCE PRODUCTS:\n• NOT A DEPOSIT • NOT FDIC INSURED • NOT INSURED BY ANY FEDERAL GOVERNMENT AGENC')
# (70, 'RAL GOVERNMENT AGENCY • NO BANK GUARANTEE • MAY LOSE VALUE')
# (71, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (72, 'ANT MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT\nCHASE TOTAL CHECKING\n®\n2\nCHASE DEBIT \nC\nARD COVERA')
# (73, 'DEBIT \nC\nARD COVERAGE SM \nA\nND FEES  3\n(Please visit \nw\nww.chase.com/checking/\ndebit-card-coverage')
# (74, 'debit-card-coverage  \nf\nor additional details.)\nChase Debit Card Coverage: You can choose how we tre')
# (75, 'an choose how we treat your everyday (not recurring) debit card \ntransactions when you don’t have en')
# (76, 'en you don’t have enough money available. Please note: Regardless of which option \nyou choose for Ch')
# (77, 'n \nyou choose for Chase Debit Card Coverage, you may also want to sign up for Overdraft Protection i')
# (78, 'erdraft Protection if you \nare eligible. Please visit www.chase.com/OverdraftProtection  for more de')
# (79, 'tection  for more details, including terms and \nconditions.\nOPTION #1 (YES): You ask us to add Chase')
# (80, 'ask us to add Chase Debit Card Coverage\nThis means you want Chase to authorize and pay your everyda')
# (81, 'and pay your everyday debit card transactions, at our \ndiscretion, when you don’t have enough money')
# (82, 't have enough money to cover a transaction (this includes available funds in \nyour linked Overdraft')
# (83, 'ur linked Overdraft Protection account, if enrolled). Overdraft Fees may apply.\nOverdraft\n$34 Overdr')
# (84, 'Overdraft\n$34 Overdraft Fee per transaction during our nightly processing beginning with \nthe first')
# (85, 'ing with \nthe first transaction that overdraws your account balance by more than $50.\n• Maximum of 3')
# (86, '$50.\n• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:\n•  With Ch')
# (87, 'raft Fee:\n•  With Chase Overdraft Assist, if you’re overdrawn by $50 or less at the end \nof the busi')
# (88, 'the end \nof the business day OR if you’re overdrawn by more than $50 and you bring \nyour account bal')
# (89, 'ng \nyour account balance to overdrawn by $50 or less at the end of the next \nbusiness day (you have')
# (90, 'iness day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit or \ntransfer). Chase Overdraft As')
# (91, '. Chase Overdraft Assist does not require enrollment and comes \nwith eligible Chase checking account')
# (92, 'ase checking accounts\n• If your transaction is $5 or less\n•  If your debit card transaction was auth')
# (93, 'transaction was authorized when there was a sufficient \navailable balance in your account\n•  If your')
# (94, 'r account\n•  If your check or ACH is returned unpaid. However, we may charge an Overdraft \nFee if a')
# (95, 'Overdraft \nFee if a previously returned check or ACH is presented again and paid\n• If your debit car')
# (96, '• If your debit card transaction or ATM cash withdrawal request is declined\nOPTION #2  (NO ):  No C')
# (97, 'ION #2  (NO ):  No Chase Debit Card Coverage (If you don’t choose an option when you \nopen your acco')
# (98, 'you \nopen your account, Option #2 (No) is automatically selected for you)\nThis means you do not wan')
# (99, 'means you do not want Chase to authorize and pay your everyday debit card transactions when \nyou don')
# (100, 'ctions when \nyou don’t have enough money to cover a transaction (this includes available funds in yo')
# (101, 'vailable funds in your linked \nOverdraft Protection account, if enrolled). Since everyday debit card')
# (102, 'everyday debit card transactions will be declined \nwhen there is not enough money available, you wo')
# (103, 'ey available, you won’t be charged an Overdraft Fee for everyday debit \ncard transactions.\nYou can a')
# (104, 'nsactions.\nYou can avoid overdrawing your account by making a deposit or transferring funds to cover')
# (105, 'rring funds to cover the overdraft before the \nbusiness day ends and we start our nightly processing')
# (106, 'r nightly processing. Here are the cutoff times for some ways of making a deposit or \ntransferring f')
# (107, 't or \ntransferring funds from another Chase account:\n• At a branch before it closes\n• At an ATM befo')
# (108, 'ses\n• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)\n• When transferring money on chase')
# (109, 'rring money on chase.com  or Chase Mobile or using Zelle before 11 p.m. Eastern Time (8 p.m. Pacific')
# (110, 'Time (8 p.m. Pacific Time)\nIf you deposit a check, this assumes we do not place a hold and the check')
# (111, 'a hold and the check is not returned. Additional cutoff times apply to \nother transfers, including t')
# (112, 'ansfers, including transfers from non-Chase accounts. Please visit chase.com or Chase Mobile for mor')
# (113, 'Chase Mobile for more information \nand service agreements.\nSee the next page for other fees that may')
# (114, 'other fees that may apply.\n3  Important details about your Chase Debit Card Coverage: An everyday d')
# (115, 'erage: An everyday debit card transaction is a one-time purchase or payment, such as groceries, gaso')
# (116, 'h as groceries, gasoline or dining out, and includes PIN and non-PIN point-of-sale \ntransactions.\tW')
# (117, 'le \ntransactions.\tW hether \to r\tn ot\tyo u\tch oose\tt o\th ave\tyo ur\te veryday\td ebit\tc ard\tt ransactio')
# (118, 'it\tc ard\tt ransactions\tc overed\tw ill\tn ot\ta ffect\tt he\tw ay\tw e\tt reat\tyo ur\tr ecurring\td ebit\tc ar')
# (119, 'ecurring\td ebit\tc ard\tt ransactions\t( such\ta s\tm onthly\tm ovie\tr entals,\tg ym\tm emberships\to r\ts ubs')
# (120, 'emberships\to r\ts ubscriptions)\t\nwhen\tyou\tdon’t\thave\tenough\tmoney\tin\tyour\taccount\tto\tcover\tthe\ttransa')
# (121, 'to\tcover\tthe\ttransactions.\tWe\tmay,\tat\tour\tdiscretion,\tauthorize\tand\tpay\ta\trecurring\tdebit\tcard\ttran')
# (122, 'ring\tdebit\tcard\ttransaction\tthat\tcauses\tan\toverdraft\tand\tcharge\tan\tOverdraft\tFee.')
# (123, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (124, 'ANT MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT\nCHASE TOTAL CHECKING\n®\n3\nHOW  \nDE\nPOSITS AND \nWITH')
# (125, 'DE\nPOSITS AND \nWITHDRAWALS \nWORK\nThe Order in \nWh\nich Withdrawals \nan\nd Deposits \nAr\ne Posted Durin')
# (126, 's \nAr\ne Posted During \nOur Nightly \nProcessing\nPosting order is the order in which we apply deposits')
# (127, 'ch we apply deposits and withdrawals to your \naccount. We provide you with visibility into how trans')
# (128, 'ility into how transactions are posted and in \nwhat order to help you better manage your account.\nWh')
# (129, 'age your account.\nWhen we transition from one business day to the next business day we post \ntransac')
# (130, 'day we post \ntransactions to and from your account during our nightly processing. The \norder in whic')
# (131, '. The \norder in which we generally post transactions during nightly processing for \neach business da')
# (132, 'or \neach business day is:\n•  First, we make any previous day adjustments, and add deposits to your\na')
# (133, 'd deposits to your\naccount.\n•  Second, we subtract transactions in chronological order by using the')
# (134, 'order by using the date\nand time of when the transaction was authorized or shown as pending.\nThis i')
# (135, 'n as pending.\nThis includes ATM and Chase banker withdrawals, transfers and payments;\nautomatic paym')
# (136, 'ents;\nautomatic payments; chase.com or Chase Mobile online transactions; checks\ndrawn on your accoun')
# (137, 'drawn on your account; debit card transactions; wire transfers; and real time\npayments. If multiple')
# (138, 'yments. If multiple transactions have the same date and time, then they\nare posted in high to low do')
# (139, 'ed in high to low dollar order.\n -  There are some instances where we do not have the time of the tr')
# (140, 'e the time of the transaction\ntherefore we post at the end of the day the transaction occurred:\n• We')
# (141, 'ction occurred:\n• We are unable to show the transaction as pending; or\n•  We don’t receive an author')
# (142, '’t receive an authorization request from the merchant but the\ntransaction is presented for payment.')
# (143, 'sented for payment.\n•  Third, there are some transactions that we cannot process automatically or\nun')
# (144, 'automatically or\nuntil we’ve completed posting of your chronological transactions. This includes\nOv')
# (145, 'ns. This includes\nOverdraft Protection transfers or transfers to maintain target balances in other\na')
# (146, 'balances in other\naccounts. We subtract these remaining transactions in high to low dollar order.\n•')
# (147, 'low dollar order.\n• Finally, fees are assessed last.\nIf you review your account during the day, you')
# (148, 'during the day, you will see that we show\nsome transactions as “pending.” For details, refer to the')
# (149, 'etails, refer to the section “Pending”\ntransactions in the Deposit Account Agreement . These transac')
# (150, 'ment . These transactions impact\nyour available balance, but have not yet posted to your account and')
# (151, 'to your account and do not\nguarantee that we will pay these transactions to your account if you hav')
# (152, 'r account if you have a\nnegative balance at that time. We may still return a transaction unpaid if y')
# (153, 'nsaction unpaid if your\nbalance has insufficient funds during that business day’s nightly processing')
# (154, 's nightly processing,\neven if it had been displayed as a “pending” transaction on a positive balance')
# (155, 'n a positive balance\nduring the day. If a transaction that you made or authorized does not display\na')
# (156, 'd does not display\nas “pending,” you are still responsible for it and it may still be posted against')
# (157, 'll be posted against\nyour account during nightly processing.\nWhen Your Deposits \nAre Available \n(S\ne')
# (158, 'Are Available \n(S\nee Funds \nAvailability Policy in \nthe Deposit Account \nAgreement for \ndetails)\n•')
# (159, 'ent for \ndetails)\n• Cash deposit – Same business day\n• Direct deposit/wire transfer – Same business')
# (160, 'fer – Same business day\n• Check deposit – Usually the next business day, but sometimes longer:\n-  If')
# (161, 'etimes longer:\n-  If we place a longer hold on a check, the first $225 will be available by the\nnext')
# (162, 'vailable by the\nnext business day\n-  The date your deposit is expected to be available will be displ')
# (163, 'ilable will be displayed on your\nreceipt\n-  In some situations, we may notify you at the time or aft')
# (164, 'u at the time or after your deposit is\nmade that your funds (including the first $225) will not be a')
# (165, '$225) will not be available for up to\nseven business days\nA “business day” is a non-holiday weekday')
# (166, 'non-holiday weekday. The cutoff times listed in the \nsection above will determine the “business day')
# (167, 'ne the “business day” for your deposit.\nOTHER ATM \nAN\nD DEBIT CARD \nFEES\nCard Replacement – Rush Req')
# (168, 'placement – Rush Request: You request express shipping of a \nreplacement debit or ATM card \n(A\nvoid')
# (169, 'r ATM card \n(A\nvoid this fee by requesting standard shipping)\n$5 p\ner card, upon request\nNon-ATM Cas')
# (170, 'request\nNon-ATM Cash: You use your Chase Debit Card to withdraw cash from \nanother financial instit')
# (171, 'her financial institution (excluding ATMs)\n3% o\nf the dollar amount of \nthe transaction OR  \n$5, w\nh')
# (172, 'saction OR  \n$5, w\nhichever is greater\nForeign Exchange Rate Adjustment: You make card purchases,')
# (173, 'e card purchases,  \nno\nn-ATM cash transactions or ATM withdrawals in a currency other \nthan U.S. dol')
# (174, 'other \nthan U.S. dollars\n3% o f withdrawal amount \nafter conversion to U.S. \ndollars. For additional')
# (175, 'lars. For additional \ninformation on foreign \nexchange rates, refer to the \nDeposit Account Agreemen')
# (176, 'sit Account Agreement\nSee the next page for other fees that may apply.')
# (177, 'CHASE TOTAL CHECKING\n®\n4\nWIRE TRANSFER \nFEES4, 5\nDomestic and International Incoming Wire: A wire tr')
# (178, 'ming Wire: A wire transfer is \ndeposited into your account\n$15 per transfer OR  \n$0 i\nf the transfer')
# (179, '$0 i\nf the transfer was \noriginally sent with the help \nof a Chase banker or using \nchase.com or Ch')
# (180, 'ing \nchase.com or Chase Mobile\nDomestic Wire: A banker helps you to send a wire to a bank account \nw')
# (181, 'to a bank account \nwithin the U.S.$35 \nper transfer\nOnline Domestic Wire: You use chase.com or Chase')
# (182, 'e chase.com or Chase Mobile to send a \nwire from your account to a bank account within the U.S. $25')
# (183, 'within the U.S. $25 per transfer\nConsumer USD/FX International Wire: A banker helps you send a wire')
# (184, 'lps you send a wire \nto a bank account outside the U.S. in either U.S. dollars (USD) or foreign \ncur')
# (185, 'USD) or foreign \ncurrency (FX)\n$50 \nper transfer\nConsumer Online USD International Wire:  You use ch')
# (186, 'al Wire:  You use chase.com or \nChase Mobile to send a wire from your account to a bank account \nout')
# (187, 'a bank account \noutside the U.S. in U.S. dollars (USD)\n$40 \nper transfer\nConsumer Online FX Interna')
# (188, 'er Online FX International Wire:  You use chase.com or Chase \nMobile to send a wire from your accoun')
# (189, 'ire from your account to a bank account outside the \nU.S. in foreign currency (FX)\n$5 per transfer O')
# (190, 'X)\n$5 per transfer OR  \n$0 p er transfer if the \namount is equal to $5,000 \nUSD or more\nFor wire tra')
# (191, 'or more\nFor wire transfers you send or we receive in a foreign currency, the exchange rate is determ')
# (192, 'hange rate is determined by us in our sole discretion \nand includes a spread, which we may make a co')
# (193, 'ich we may make a commission from when completing the foreign currency exchange. You should \nexpect')
# (194, 'You should \nexpect that these foreign exchange rates will be less favorable than rates quoted onlin')
# (195, 'n rates quoted online or in publications. For additional \ninformation on these rates, refer to the D')
# (196, 'ates, refer to the Deposit Account Agreement  and Wire Transfers Agreements.\nOTHER FEES\nStop Payment')
# (197, 'ER FEES\nStop Payment: You contact us and a banker places your stop payment \nrequest on a check or AC')
# (198, 'est on a check or ACH$30 p er request\nOnline or Automated Phone Stop Payment: You use chase.com , Ch')
# (199, 'u use chase.com , Chase \nMobile or our automated phone system to place a stop payment on a \ncheck. O')
# (200, 'yment on a \ncheck. Only some types of stop payments are available\n$25 p\ner request\nOrder for Checks')
# (201, 'st\nOrder for Checks or Supplies: An order of personal checks, deposit \nslips or other banking suppli')
# (202, 'other banking supplies\nVaries (based on items \nordered)\nCounter Check: A blank page of 3 personal ch')
# (203, 'age of 3 personal checks we print upon your \nrequest at a branch$3 per page\nMoney Order: A check iss')
# (204, 'y Order: A check issued by you, purchased at a branch, for an \namount up to $1,000$5 p\ner check\nCash')
# (205, '00$5 p\ner check\nCashier’s Check: A check issued by the bank, purchased at a branch, \nfor any amount')
# (206, 'ch, \nfor any amount and to a payee you designate$10 per check\nLegal Processing: Processing of any ga')
# (207, 'Processing of any garnishment, tax levy, or other \ncourt administrative order against your accounts,')
# (208, 'ainst your accounts, whether or not the \nfunds are actually paid\nUp to $100 per order\nSAFE DEPOSIT B')
# (209, 'order\nSAFE DEPOSIT BOX \nANNUAL RENT\nAssessed annually at lease renewal. We currently do not rent new')
# (210, 'ntly do not rent new Safe \nDeposit Boxes\nVaries by size and location, \nincludes sales tax where \napp')
# (211, 'sales tax where \napplicable (disclosed on your \nannual invoice)\n4\t \tFinancial\tinstitutions\tmay\tdedu')
# (212, 'stitutions\tmay\tdedu ct\tpro cessing\tfee s\tand/ or\tcharg es\tfro m\tthe\tamou nt\tof\tthe\tinco ming\tor\tout')
# (213, 'he\tinco ming\tor\tout going\twire\ttran sfers,\tinclu ding\ton\tretu rned\twire\ttran sfers.\tAny\tdedu ctions')
# (214, 'rs.\tAny\tdedu ctions\ttake n\tby\tus,\tand\tour\taffili ates,\tmay\tinclu de\t\nprocessing fees charged by Chas')
# (215, 'fees charged by Chase.\n5\t \tWe\tmay\tuse\tan y\tfu nds\ttr ansfer\tsy stem\twe\tbe lieve\tre asonable\tto\tco mp')
# (216, 're asonable\tto\tco mplete\tyo ur\tre quest,\tre gardless\tof\tan y\tin structions\tyo u\tmi ght\tgi ve\tus .\tIf')
# (217, 'mi ght\tgi ve\tus .\tIf\twe\tal so\tar e\tth e\tre cipient’s\tba nk,\twe\tma y\tco mplete\tyo ur\tre quest\tus ing')
# (218, 'ur\tre quest\tus ing\tan\tin ternal\t\ntransfer, and assess a wire transfer fee.\nHAVE QUESTIONS? CALL US')
# (219, 'QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE THE D')
# (220, 'ORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT\nJPMorgan Chase Bank, N.A. Member FDIC\n© 2024 JPMorgan C')
# (221, 'IC\n© 2024 JPMorgan Chase & Co.\nEffective 11/17/2024\nFEETABLE-TOTAL-1124-ONLN')

# %% [markdown]
# #### Recursive Character Text Splitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(
    
    separators="",
    chunk_size=100,
    chunk_overlap=20
)

# %%
chunks=[]

for doc in documents:
    
    texts=text_splitter.split_text(doc.page_content)
    chunks.extend(texts)

# %%
for chunk in enumerate(chunks):
    print(chunk)
# Out:
# (0, 'HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (1, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (2, '1\nCHASE TOTAL CHECKING\n®\nA GUIDE TO YOUR ACCOUNT †')
# (3, 'It’s important that you understand how your Chase Total Checking account works.')
# (4, 'We’ve created this Guide to explain the fees and some key terms of your personal account.\nMONTHLY')
# (5, 'MONTHLY \nSERVICE FEE*\nMonthly Service Fee $12\nWays to Avoid the \nMonthly Service Fee')
# (6, 'Monthly Service Fee\n$0 Monthly Service Fee when you have any ONE  of the following during each')
# (7, 'monthly statement period:')
# (8, '•  Electronic deposits made into this account totaling $500 or more, such as')
# (9, 'payments from payroll providers or government benefit providers, by using')
# (10, '(i) the ACH network, (ii) the Real Time Payment or FedNow SM network, or  \n(ii')
# (11, '(ii\ni) third party services that facilitate payments to your debit card using the')
# (12, 'Visa® or Mastercard® network')
# (13, '• OR, a balance at the beginning of each day of $1,500 or more in this account')
# (14, '•  OR, an average beginning day balance of $5,000 or more in any combination')
# (15, 'of this account and linked qualifying deposits 1/investments 2\nATM FEES\nNon-Chase ATM')
# (16, 'Non-Chase ATM \n(Avoid these fees by \nusing a Chase ATM)')
# (17, 'using a Chase ATM)\n$3 per withdrawal at a non-Chase ATM in the U.S. and the U.S. territories')
# (18, '$5 per withdrawal at a non-Chase ATM outside the U.S. and the U.S. territories')
# (19, 'Surcharge Fees from the ATM owner/network still apply. U.S. territories include')
# (20, 'American Samoa, Guam, the Northern Mariana Islands, Puerto Rico, and the \nU.S. Virgin Islands')
# (21, 'Fees for using your account when you don’t have enough money in it or it’s already overdrawn')
# (22, 'OVERDRAFT FEES\nOverdraft:\nChase pays a \ntransaction \nduring our nightly \nprocessing \non a business')
# (23, 'on a business \nday when your \naccount balance is \noverdrawn')
# (24, 'overdrawn\n$34 Overdraft Fee per transaction during our nightly processing beginning with')
# (25, 'the first transaction that overdraws your account balance by more than $50.')
# (26, '• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:')
# (27, '•  With Chase Overdraft Assist SM, if you’re overdrawn by $50 or less at the')
# (28, 'end of the business day OR if you’re overdrawn by more than $50 and you')
# (29, 'bring your account balance to overdrawn by $50 or less at the end of the')
# (30, 'next business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit')
# (31, 'or transfer). Chase Overdraft Assist does not require enrollment and comes')
# (32, 'with eligible Chase checking accounts\n• If your transaction is $5 or less')
# (33, '•  If your debit card transaction was authorized when there was a sufficient')
# (34, 'available balance in your account')
# (35, '•  If your check or ACH is returned unpaid. However, we may charge an Overdraft')
# (36, 'Fee if a previously returned check or ACH is presented again and paid')
# (37, '• If your debit card transaction or ATM cash withdrawal request is declined')
# (38, 'You can avoid overdrawing your account by making a deposit or transferring funds to cover the')
# (39, 'funds to cover the overdraft before the')
# (40, 'business day ends and we start our nightly processing. Here are the cutoff times for some ways of')
# (41, 'for some ways of making a deposit or')
# (42, 'transferring funds from another Chase account:\n• At a branch before it closes')
# (43, '• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (44, '• When transferring money on chase.com  or Chase Mobile® or using Zelle® before 11 p.m. Eastern')
# (45, '11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (46, 'If you deposit a check, this assumes we do not place a hold and the check is not returned.')
# (47, 'is not returned. Additional cutoff times apply to')
# (48, 'other transfers, including transfers from non-Chase accounts. Please visit chase.com or Chase')
# (49, 'chase.com or Chase Mobile for more information')
# (50, 'and service agreements.')
# (51, '†  For the complete terms governing your account, please consult the Deposit Account Agreement .')
# (52, 'Account Agreement . The terms of the account, including any fees or features, may change.')
# (53, '*\t \tNew\tand\tconverted\tacco unts\twill\tnot\tbe\tchar ged\ta\tMonth ly\tServi ce\tFee\tfor\tat\tleas')
# (54, 'ce\tFee\tfor\tat\tleas t\tthe\tfirst\ttwo\tstat ement\tperi ods.\tAfte r\tthat\tthe\tMont hly\tServi')
# (55, 'hly\tServi ce\tFee\twill\tappl y\tunles s\tyou\tmeet\tone\tof\tthe\tways\tto\tavoi d\tthe\tMont hly\tServi ce')
# (56, 'Fee each statement period (if applicable).')
# (57, '1   Qualifying personal deposits include Chase First Checking SM accounts, personal Chase savings')
# (58, 'Chase savings accounts (excluding Chase Premier Savings SM and Chase Private Client Savings SM),')
# (59, 'Client Savings SM), CDs, certain Chase Retirement CDs, and certain')
# (60, 'Chase Retirement Money Market Accounts.')
# (61, '2\t \tQualifying\tperso nal\tinvest ments\tinclude\tbalanc es\tin\tinvest ment\tand\tannuity\tproduc')
# (62, 'ts\toffered\tthroug h\tJPMor gan\tChase\t&\tCo.\tand\tits\taffiliate s\tand\tagenci es.\tFor\tmost\tproduc')
# (63, 'es.\tFor\tmost\tproduc ts,\twe\tuse\tdaily\tbalanc es\tto\tcalcu late\tthe')
# (64, 'average beginning day balance for such investment and annuity products. Some third party providers')
# (65, 'party providers report balances on a weekly, not daily, basis and we will use the most current')
# (66, 'the most current balance reported. Balances in 529 plans,')
# (67, 'don')
# (68, 'or-advised funds, and certain retirement plan investment accounts do not qualify. Investment')
# (69, 'qualify. Investment products and related services are only available in English.')
# (70, 'J.P.\tMorgan\tWeal th\tMana gement\tis\ta\tbusi ness\tof\tJPMo rgan\tChas e\t&\tCo.,\twhic h\toffer s\tinve')
# (71, 'h\toffer s\tinve stment\tprod ucts\tand\tservi ces\tthro ugh\tJ.P. Morgan Securities')
# (72, 'Morgan Securities LLC\t(JPMS),\ta\tregistered\tbrok er-dealer\tand\tinve stment\tadvise r,')
# (73, 'member FINRA and SIPC. Insurance products are made available through Chase Insurance Agency, Inc.')
# (74, 'Agency, Inc. (CIA), a licensed insurance agency, doing business as Chase Insurance Agency Services,')
# (75, 'Agency Services, Inc. in Florida. Certain custody')
# (76, 'and\tother\tservices\tare\tprovided\tby\tJPMorgan\tChase\tBank,\tN.A.\t(JPMCB).\tJPMS,\tCIA\tand\tJPMCB\tare\taffil')
# (77, 'and\tJPMCB\tare\taffiliated\tcompanies\tunder\tthe\tcommon\tcontrol\tof\tJPMorgan\tChase\t&\tCo.\tProducts\tnot\tav')
# (78, 'Co.\tProducts\tnot\tavailable\tin\tall\tstates.')
# (79, 'INVESTMENT AND INSURANCE PRODUCTS:')
# (80, '• NOT A DEPOSIT • NOT FDIC INSURED • NOT INSURED BY ANY FEDERAL GOVERNMENT AGENCY • NO BANK')
# (81, 'AGENCY • NO BANK GUARANTEE • MAY LOSE VALUE')
# (82, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (83, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (84, 'CHASE TOTAL CHECKING\n®\n2\nCHASE DEBIT \nC\nARD COVERAGE SM \nA\nND FEES  3\n(Please visit \nw')
# (85, '(Please visit \nw\nww.chase.com/checking/\ndebit-card-coverage  \nf\nor additional details.)')
# (86, 'Chase Debit Card Coverage: You can choose how we treat your everyday (not recurring) debit card')
# (87, 'transactions when you don’t have enough money available. Please note: Regardless of which option')
# (88, 'you choose for Chase Debit Card Coverage, you may also want to sign up for Overdraft Protection if')
# (89, 'Protection if you')
# (90, 'are eligible. Please visit www.chase.com/OverdraftProtection  for more details, including terms and')
# (91, 'including terms and')
# (92, 'conditions.\nOPTION #1 (YES): You ask us to add Chase Debit Card Coverage')
# (93, 'This means you want Chase to authorize and pay your everyday debit card transactions, at our')
# (94, 'discretion, when you don’t have enough money to cover a transaction (this includes available funds')
# (95, 'available funds in')
# (96, 'your linked Overdraft Protection account, if enrolled). Overdraft Fees may apply.\nOverdraft')
# (97, 'Overdraft\n$34 Overdraft Fee per transaction during our nightly processing beginning with')
# (98, 'the first transaction that overdraws your account balance by more than $50.')
# (99, '• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:')
# (100, '•  With Chase Overdraft Assist, if you’re overdrawn by $50 or less at the end')
# (101, 'of the business day OR if you’re overdrawn by more than $50 and you bring')
# (102, 'your account balance to overdrawn by $50 or less at the end of the next')
# (103, 'business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit or')
# (104, 'transfer). Chase Overdraft Assist does not require enrollment and comes')
# (105, 'with eligible Chase checking accounts\n• If your transaction is $5 or less')
# (106, '•  If your debit card transaction was authorized when there was a sufficient')
# (107, 'available balance in your account')
# (108, '•  If your check or ACH is returned unpaid. However, we may charge an Overdraft')
# (109, 'Fee if a previously returned check or ACH is presented again and paid')
# (110, '• If your debit card transaction or ATM cash withdrawal request is declined')
# (111, 'OPTION #2  (NO ):  No Chase Debit Card Coverage (If you don’t choose an option when you')
# (112, 'open your account, Option #2 (No) is automatically selected for you)')
# (113, 'This means you do not want Chase to authorize and pay your everyday debit card transactions when')
# (114, 'you don’t have enough money to cover a transaction (this includes available funds in your linked')
# (115, 'Overdraft Protection account, if enrolled). Since everyday debit card transactions will be declined')
# (116, 'will be declined')
# (117, 'when there is not enough money available, you won’t be charged an Overdraft Fee for everyday debit')
# (118, 'card transactions.')
# (119, 'You can avoid overdrawing your account by making a deposit or transferring funds to cover the')
# (120, 'funds to cover the overdraft before the')
# (121, 'business day ends and we start our nightly processing. Here are the cutoff times for some ways of')
# (122, 'for some ways of making a deposit or')
# (123, 'transferring funds from another Chase account:\n• At a branch before it closes')
# (124, '• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (125, '• When transferring money on chase.com  or Chase Mobile or using Zelle before 11 p.m. Eastern Time')
# (126, 'p.m. Eastern Time (8 p.m. Pacific Time)')
# (127, 'If you deposit a check, this assumes we do not place a hold and the check is not returned.')
# (128, 'is not returned. Additional cutoff times apply to')
# (129, 'other transfers, including transfers from non-Chase accounts. Please visit chase.com or Chase')
# (130, 'chase.com or Chase Mobile for more information')
# (131, 'and service agreements.\nSee the next page for other fees that may apply.')
# (132, '3  Important details about your Chase Debit Card Coverage: An everyday debit card transaction is a')
# (133, 'transaction is a one-time purchase or payment, such as groceries, gasoline or dining out, and')
# (134, 'or dining out, and includes PIN and non-PIN point-of-sale')
# (135, 'transactions.\tW hether \to r\tn ot\tyo u\tch oose\tt o\th ave\tyo ur\te veryday\td ebit\tc ard\tt')
# (136, 'ebit\tc ard\tt ransactions\tc overed\tw ill\tn ot\ta ffect\tt he\tw ay\tw e\tt reat\tyo ur\tr ecurring\td ebit\tc')
# (137, 'ecurring\td ebit\tc ard\tt ransactions\t( such\ta s\tm onthly\tm ovie\tr entals,\tg ym\tm emberships\to r\ts')
# (138, 'emberships\to r\ts ubscriptions)')
# (139, 'when\tyou\tdon’t\thave\tenough\tmoney\tin\tyour\taccount\tto\tcover\tthe\ttransactions.\tWe\tmay,\tat\tour\tdiscreti')
# (140, 'may,\tat\tour\tdiscretion,\tauthorize\tand\tpay\ta\trecurring\tdebit\tcard\ttransaction\tthat\tcauses\tan\toverdraf')
# (141, 't\tcauses\tan\toverdraft\tand\tcharge\tan\tOverdraft\tFee.')
# (142, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (143, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (144, 'CHASE TOTAL CHECKING\n®\n3\nHOW  \nDE\nPOSITS AND \nWITHDRAWALS \nWORK\nThe Order in \nWh\nich Withdrawals')
# (145, 'Wh\nich Withdrawals \nan\nd Deposits \nAr\ne Posted During \nOur Nightly \nProcessing')
# (146, 'Processing\nPosting order is the order in which we apply deposits and withdrawals to your')
# (147, 'account. We provide you with visibility into how transactions are posted and in')
# (148, 'what order to help you better manage your account.')
# (149, 'When we transition from one business day to the next business day we post')
# (150, 'transactions to and from your account during our nightly processing. The')
# (151, 'order in which we generally post transactions during nightly processing for \neach business day is:')
# (152, '•  First, we make any previous day adjustments, and add deposits to your\naccount.')
# (153, 'account.\n•  Second, we subtract transactions in chronological order by using the date')
# (154, 'and time of when the transaction was authorized or shown as pending.')
# (155, 'This includes ATM and Chase banker withdrawals, transfers and payments;')
# (156, 'automatic payments; chase.com or Chase Mobile online transactions; checks')
# (157, 'drawn on your account; debit card transactions; wire transfers; and real time')
# (158, 'payments. If multiple transactions have the same date and time, then they')
# (159, 'are posted in high to low dollar order.')
# (160, '-  There are some instances where we do not have the time of the transaction')
# (161, 'therefore we post at the end of the day the transaction occurred:')
# (162, '• We are unable to show the transaction as pending; or')
# (163, '•  We don’t receive an authorization request from the merchant but the')
# (164, 'transaction is presented for payment.')
# (165, '•  Third, there are some transactions that we cannot process automatically or')
# (166, 'until we’ve completed posting of your chronological transactions. This includes')
# (167, 'Overdraft Protection transfers or transfers to maintain target balances in other')
# (168, 'accounts. We subtract these remaining transactions in high to low dollar order.')
# (169, '• Finally, fees are assessed last.')
# (170, 'If you review your account during the day, you will see that we show')
# (171, 'some transactions as “pending.” For details, refer to the section “Pending”')
# (172, 'transactions in the Deposit Account Agreement . These transactions impact')
# (173, 'your available balance, but have not yet posted to your account and do not')
# (174, 'guarantee that we will pay these transactions to your account if you have a')
# (175, 'negative balance at that time. We may still return a transaction unpaid if your')
# (176, 'balance has insufficient funds during that business day’s nightly processing,')
# (177, 'even if it had been displayed as a “pending” transaction on a positive balance')
# (178, 'during the day. If a transaction that you made or authorized does not display')
# (179, 'as “pending,” you are still responsible for it and it may still be posted against')
# (180, 'your account during nightly processing.\nWhen Your Deposits \nAre Available \n(S\nee Funds')
# (181, '(S\nee Funds \nAvailability Policy in \nthe Deposit Account \nAgreement for \ndetails)')
# (182, 'details)\n• Cash deposit – Same business day\n• Direct deposit/wire transfer – Same business day')
# (183, '• Check deposit – Usually the next business day, but sometimes longer:')
# (184, '-  If we place a longer hold on a check, the first $225 will be available by the\nnext business day')
# (185, 'next business day\n-  The date your deposit is expected to be available will be displayed on your')
# (186, 'receipt\n-  In some situations, we may notify you at the time or after your deposit is')
# (187, 'made that your funds (including the first $225) will not be available for up to\nseven business days')
# (188, 'seven business days\nA “business day” is a non-holiday weekday. The cutoff times listed in the')
# (189, 'section above will determine the “business day” for your deposit.\nOTHER ATM \nAN\nD DEBIT CARD \nFEES')
# (190, 'D DEBIT CARD \nFEES\nCard Replacement – Rush Request: You request express shipping of a')
# (191, 'replacement debit or ATM card \n(A\nvoid this fee by requesting standard shipping)\n$5 p')
# (192, '$5 p\ner card, upon request\nNon-ATM Cash: You use your Chase Debit Card to withdraw cash from')
# (193, 'another financial institution (excluding ATMs)\n3% o\nf the dollar amount of \nthe transaction OR')
# (194, '$5, w\nhichever is greater\nForeign Exchange Rate Adjustment: You make card purchases,  \nno')
# (195, 'no\nn-ATM cash transactions or ATM withdrawals in a currency other \nthan U.S. dollars')
# (196, 'than U.S. dollars\n3% o f withdrawal amount \nafter conversion to U.S. \ndollars. For additional')
# (197, 'information on foreign \nexchange rates, refer to the \nDeposit Account Agreement')
# (198, 'See the next page for other fees that may apply.')
# (199, 'CHASE TOTAL CHECKING\n®\n4\nWIRE TRANSFER \nFEES4, 5')
# (200, 'FEES4, 5\nDomestic and International Incoming Wire: A wire transfer is \ndeposited into your account')
# (201, '$15 per transfer OR  \n$0 i\nf the transfer was \noriginally sent with the help')
# (202, 'of a Chase banker or using \nchase.com or Chase Mobile')
# (203, 'Domestic Wire: A banker helps you to send a wire to a bank account \nwithin the U.S.$35')
# (204, 'within the U.S.$35 \nper transfer\nOnline Domestic Wire: You use chase.com or Chase Mobile to send a')
# (205, 'wire from your account to a bank account within the U.S. $25 per transfer')
# (206, 'Consumer USD/FX International Wire: A banker helps you send a wire')
# (207, 'to a bank account outside the U.S. in either U.S. dollars (USD) or foreign \ncurrency (FX)\n$50')
# (208, 'currency (FX)\n$50 \nper transfer\nConsumer Online USD International Wire:  You use chase.com or')
# (209, 'Chase Mobile to send a wire from your account to a bank account')
# (210, 'outside the U.S. in U.S. dollars (USD)\n$40 \nper transfer')
# (211, '$40 \nper transfer\nConsumer Online FX International Wire:  You use chase.com or Chase')
# (212, 'Mobile to send a wire from your account to a bank account outside the')
# (213, 'U.S. in foreign currency (FX)\n$5 per transfer OR  \n$0 p er transfer if the')
# (214, 'amount is equal to $5,000 \nUSD or more')
# (215, 'For wire transfers you send or we receive in a foreign currency, the exchange rate is determined by')
# (216, 'is determined by us in our sole discretion')
# (217, 'and includes a spread, which we may make a commission from when completing the foreign currency')
# (218, 'foreign currency exchange. You should')
# (219, 'expect that these foreign exchange rates will be less favorable than rates quoted online or in')
# (220, 'quoted online or in publications. For additional')
# (221, 'information on these rates, refer to the Deposit Account Agreement  and Wire Transfers Agreements.')
# (222, 'OTHER FEES\nStop Payment: You contact us and a banker places your stop payment')
# (223, 'request on a check or ACH$30 p er request')
# (224, 'Online or Automated Phone Stop Payment: You use chase.com , Chase')
# (225, 'Mobile or our automated phone system to place a stop payment on a')
# (226, 'check. Only some types of stop payments are available\n$25 p\ner request')
# (227, '$25 p\ner request\nOrder for Checks or Supplies: An order of personal checks, deposit')
# (228, 'slips or other banking supplies\nVaries (based on items \nordered)')
# (229, 'ordered)\nCounter Check: A blank page of 3 personal checks we print upon your')
# (230, 'request at a branch$3 per page\nMoney Order: A check issued by you, purchased at a branch, for an')
# (231, 'amount up to $1,000$5 p\ner check')
# (232, 'er check\nCashier’s Check: A check issued by the bank, purchased at a branch,')
# (233, 'for any amount and to a payee you designate$10 per check')
# (234, 'Legal Processing: Processing of any garnishment, tax levy, or other')
# (235, 'court administrative order against your accounts, whether or not the \nfunds are actually paid')
# (236, 'Up to $100 per order\nSAFE DEPOSIT BOX \nANNUAL RENT')
# (237, 'ANNUAL RENT\nAssessed annually at lease renewal. We currently do not rent new Safe \nDeposit Boxes')
# (238, 'Deposit Boxes\nVaries by size and location, \nincludes sales tax where')
# (239, 'applicable (disclosed on your \nannual invoice)')
# (240, '4\t \tFinancial\tinstitutions\tmay\tdedu ct\tpro cessing\tfee s\tand/ or\tcharg es\tfro m\tthe\tamou')
# (241, 'es\tfro m\tthe\tamou nt\tof\tthe\tinco ming\tor\tout going\twire\ttran sfers,\tinclu ding\ton\tretu')
# (242, 'ding\ton\tretu rned\twire\ttran sfers.\tAny\tdedu ctions\ttake n\tby\tus,\tand\tour\taffili ates,\tmay\tinclu de')
# (243, 'processing fees charged by Chase.')
# (244, '5\t \tWe\tmay\tuse\tan y\tfu nds\ttr ansfer\tsy stem\twe\tbe lieve\tre asonable\tto\tco mplete\tyo ur\tre')
# (245, 'mplete\tyo ur\tre quest,\tre gardless\tof\tan y\tin structions\tyo u\tmi ght\tgi ve\tus .\tIf\twe\tal so\tar e\tth')
# (246, 'so\tar e\tth e\tre cipient’s\tba nk,\twe\tma y\tco mplete\tyo ur\tre quest\tus ing\tan\tin ternal')
# (247, 'transfer, and assess a wire transfer fee.')
# (248, 'HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (249, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (250, 'JPMorgan Chase Bank, N.A. Member FDIC\n© 2024 JPMorgan Chase & Co.\nEffective 11/17/2024')
# (251, 'FEETABLE-TOTAL-1124-ONLN')

# %% [markdown]
# #### Semantic Chunker

# %%
from langchain_experimental.text_splitter import SemanticChunker

from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLm-L6-v2")

test_splitter=SemanticChunker(embeddings)

# %%
chunks=[]

for doc in documents:
    
    texts=text_splitter.split_text(doc.page_content)
    chunks.extend(texts)

# %%
for chunk in enumerate(chunks):
    print(chunk)
# Out:
# (0, 'HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (1, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (2, '1\nCHASE TOTAL CHECKING\n®\nA GUIDE TO YOUR ACCOUNT †')
# (3, 'It’s important that you understand how your Chase Total Checking account works.')
# (4, 'We’ve created this Guide to explain the fees and some key terms of your personal account.\nMONTHLY')
# (5, 'MONTHLY \nSERVICE FEE*\nMonthly Service Fee $12\nWays to Avoid the \nMonthly Service Fee')
# (6, 'Monthly Service Fee\n$0 Monthly Service Fee when you have any ONE  of the following during each')
# (7, 'monthly statement period:')
# (8, '•  Electronic deposits made into this account totaling $500 or more, such as')
# (9, 'payments from payroll providers or government benefit providers, by using')
# (10, '(i) the ACH network, (ii) the Real Time Payment or FedNow SM network, or  \n(ii')
# (11, '(ii\ni) third party services that facilitate payments to your debit card using the')
# (12, 'Visa® or Mastercard® network')
# (13, '• OR, a balance at the beginning of each day of $1,500 or more in this account')
# (14, '•  OR, an average beginning day balance of $5,000 or more in any combination')
# (15, 'of this account and linked qualifying deposits 1/investments 2\nATM FEES\nNon-Chase ATM')
# (16, 'Non-Chase ATM \n(Avoid these fees by \nusing a Chase ATM)')
# (17, 'using a Chase ATM)\n$3 per withdrawal at a non-Chase ATM in the U.S. and the U.S. territories')
# (18, '$5 per withdrawal at a non-Chase ATM outside the U.S. and the U.S. territories')
# (19, 'Surcharge Fees from the ATM owner/network still apply. U.S. territories include')
# (20, 'American Samoa, Guam, the Northern Mariana Islands, Puerto Rico, and the \nU.S. Virgin Islands')
# (21, 'Fees for using your account when you don’t have enough money in it or it’s already overdrawn')
# (22, 'OVERDRAFT FEES\nOverdraft:\nChase pays a \ntransaction \nduring our nightly \nprocessing \non a business')
# (23, 'on a business \nday when your \naccount balance is \noverdrawn')
# (24, 'overdrawn\n$34 Overdraft Fee per transaction during our nightly processing beginning with')
# (25, 'the first transaction that overdraws your account balance by more than $50.')
# (26, '• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:')
# (27, '•  With Chase Overdraft Assist SM, if you’re overdrawn by $50 or less at the')
# (28, 'end of the business day OR if you’re overdrawn by more than $50 and you')
# (29, 'bring your account balance to overdrawn by $50 or less at the end of the')
# (30, 'next business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit')
# (31, 'or transfer). Chase Overdraft Assist does not require enrollment and comes')
# (32, 'with eligible Chase checking accounts\n• If your transaction is $5 or less')
# (33, '•  If your debit card transaction was authorized when there was a sufficient')
# (34, 'available balance in your account')
# (35, '•  If your check or ACH is returned unpaid. However, we may charge an Overdraft')
# (36, 'Fee if a previously returned check or ACH is presented again and paid')
# (37, '• If your debit card transaction or ATM cash withdrawal request is declined')
# (38, 'You can avoid overdrawing your account by making a deposit or transferring funds to cover the')
# (39, 'funds to cover the overdraft before the')
# (40, 'business day ends and we start our nightly processing. Here are the cutoff times for some ways of')
# (41, 'for some ways of making a deposit or')
# (42, 'transferring funds from another Chase account:\n• At a branch before it closes')
# (43, '• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (44, '• When transferring money on chase.com  or Chase Mobile® or using Zelle® before 11 p.m. Eastern')
# (45, '11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (46, 'If you deposit a check, this assumes we do not place a hold and the check is not returned.')
# (47, 'is not returned. Additional cutoff times apply to')
# (48, 'other transfers, including transfers from non-Chase accounts. Please visit chase.com or Chase')
# (49, 'chase.com or Chase Mobile for more information')
# (50, 'and service agreements.')
# (51, '†  For the complete terms governing your account, please consult the Deposit Account Agreement .')
# (52, 'Account Agreement . The terms of the account, including any fees or features, may change.')
# (53, '*\t \tNew\tand\tconverted\tacco unts\twill\tnot\tbe\tchar ged\ta\tMonth ly\tServi ce\tFee\tfor\tat\tleas')
# (54, 'ce\tFee\tfor\tat\tleas t\tthe\tfirst\ttwo\tstat ement\tperi ods.\tAfte r\tthat\tthe\tMont hly\tServi')
# (55, 'hly\tServi ce\tFee\twill\tappl y\tunles s\tyou\tmeet\tone\tof\tthe\tways\tto\tavoi d\tthe\tMont hly\tServi ce')
# (56, 'Fee each statement period (if applicable).')
# (57, '1   Qualifying personal deposits include Chase First Checking SM accounts, personal Chase savings')
# (58, 'Chase savings accounts (excluding Chase Premier Savings SM and Chase Private Client Savings SM),')
# (59, 'Client Savings SM), CDs, certain Chase Retirement CDs, and certain')
# (60, 'Chase Retirement Money Market Accounts.')
# (61, '2\t \tQualifying\tperso nal\tinvest ments\tinclude\tbalanc es\tin\tinvest ment\tand\tannuity\tproduc')
# (62, 'ts\toffered\tthroug h\tJPMor gan\tChase\t&\tCo.\tand\tits\taffiliate s\tand\tagenci es.\tFor\tmost\tproduc')
# (63, 'es.\tFor\tmost\tproduc ts,\twe\tuse\tdaily\tbalanc es\tto\tcalcu late\tthe')
# (64, 'average beginning day balance for such investment and annuity products. Some third party providers')
# (65, 'party providers report balances on a weekly, not daily, basis and we will use the most current')
# (66, 'the most current balance reported. Balances in 529 plans,')
# (67, 'don')
# (68, 'or-advised funds, and certain retirement plan investment accounts do not qualify. Investment')
# (69, 'qualify. Investment products and related services are only available in English.')
# (70, 'J.P.\tMorgan\tWeal th\tMana gement\tis\ta\tbusi ness\tof\tJPMo rgan\tChas e\t&\tCo.,\twhic h\toffer s\tinve')
# (71, 'h\toffer s\tinve stment\tprod ucts\tand\tservi ces\tthro ugh\tJ.P. Morgan Securities')
# (72, 'Morgan Securities LLC\t(JPMS),\ta\tregistered\tbrok er-dealer\tand\tinve stment\tadvise r,')
# (73, 'member FINRA and SIPC. Insurance products are made available through Chase Insurance Agency, Inc.')
# (74, 'Agency, Inc. (CIA), a licensed insurance agency, doing business as Chase Insurance Agency Services,')
# (75, 'Agency Services, Inc. in Florida. Certain custody')
# (76, 'and\tother\tservices\tare\tprovided\tby\tJPMorgan\tChase\tBank,\tN.A.\t(JPMCB).\tJPMS,\tCIA\tand\tJPMCB\tare\taffil')
# (77, 'and\tJPMCB\tare\taffiliated\tcompanies\tunder\tthe\tcommon\tcontrol\tof\tJPMorgan\tChase\t&\tCo.\tProducts\tnot\tav')
# (78, 'Co.\tProducts\tnot\tavailable\tin\tall\tstates.')
# (79, 'INVESTMENT AND INSURANCE PRODUCTS:')
# (80, '• NOT A DEPOSIT • NOT FDIC INSURED • NOT INSURED BY ANY FEDERAL GOVERNMENT AGENCY • NO BANK')
# (81, 'AGENCY • NO BANK GUARANTEE • MAY LOSE VALUE')
# (82, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (83, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (84, 'CHASE TOTAL CHECKING\n®\n2\nCHASE DEBIT \nC\nARD COVERAGE SM \nA\nND FEES  3\n(Please visit \nw')
# (85, '(Please visit \nw\nww.chase.com/checking/\ndebit-card-coverage  \nf\nor additional details.)')
# (86, 'Chase Debit Card Coverage: You can choose how we treat your everyday (not recurring) debit card')
# (87, 'transactions when you don’t have enough money available. Please note: Regardless of which option')
# (88, 'you choose for Chase Debit Card Coverage, you may also want to sign up for Overdraft Protection if')
# (89, 'Protection if you')
# (90, 'are eligible. Please visit www.chase.com/OverdraftProtection  for more details, including terms and')
# (91, 'including terms and')
# (92, 'conditions.\nOPTION #1 (YES): You ask us to add Chase Debit Card Coverage')
# (93, 'This means you want Chase to authorize and pay your everyday debit card transactions, at our')
# (94, 'discretion, when you don’t have enough money to cover a transaction (this includes available funds')
# (95, 'available funds in')
# (96, 'your linked Overdraft Protection account, if enrolled). Overdraft Fees may apply.\nOverdraft')
# (97, 'Overdraft\n$34 Overdraft Fee per transaction during our nightly processing beginning with')
# (98, 'the first transaction that overdraws your account balance by more than $50.')
# (99, '• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:')
# (100, '•  With Chase Overdraft Assist, if you’re overdrawn by $50 or less at the end')
# (101, 'of the business day OR if you’re overdrawn by more than $50 and you bring')
# (102, 'your account balance to overdrawn by $50 or less at the end of the next')
# (103, 'business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit or')
# (104, 'transfer). Chase Overdraft Assist does not require enrollment and comes')
# (105, 'with eligible Chase checking accounts\n• If your transaction is $5 or less')
# (106, '•  If your debit card transaction was authorized when there was a sufficient')
# (107, 'available balance in your account')
# (108, '•  If your check or ACH is returned unpaid. However, we may charge an Overdraft')
# (109, 'Fee if a previously returned check or ACH is presented again and paid')
# (110, '• If your debit card transaction or ATM cash withdrawal request is declined')
# (111, 'OPTION #2  (NO ):  No Chase Debit Card Coverage (If you don’t choose an option when you')
# (112, 'open your account, Option #2 (No) is automatically selected for you)')
# (113, 'This means you do not want Chase to authorize and pay your everyday debit card transactions when')
# (114, 'you don’t have enough money to cover a transaction (this includes available funds in your linked')
# (115, 'Overdraft Protection account, if enrolled). Since everyday debit card transactions will be declined')
# (116, 'will be declined')
# (117, 'when there is not enough money available, you won’t be charged an Overdraft Fee for everyday debit')
# (118, 'card transactions.')
# (119, 'You can avoid overdrawing your account by making a deposit or transferring funds to cover the')
# (120, 'funds to cover the overdraft before the')
# (121, 'business day ends and we start our nightly processing. Here are the cutoff times for some ways of')
# (122, 'for some ways of making a deposit or')
# (123, 'transferring funds from another Chase account:\n• At a branch before it closes')
# (124, '• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (125, '• When transferring money on chase.com  or Chase Mobile or using Zelle before 11 p.m. Eastern Time')
# (126, 'p.m. Eastern Time (8 p.m. Pacific Time)')
# (127, 'If you deposit a check, this assumes we do not place a hold and the check is not returned.')
# (128, 'is not returned. Additional cutoff times apply to')
# (129, 'other transfers, including transfers from non-Chase accounts. Please visit chase.com or Chase')
# (130, 'chase.com or Chase Mobile for more information')
# (131, 'and service agreements.\nSee the next page for other fees that may apply.')
# (132, '3  Important details about your Chase Debit Card Coverage: An everyday debit card transaction is a')
# (133, 'transaction is a one-time purchase or payment, such as groceries, gasoline or dining out, and')
# (134, 'or dining out, and includes PIN and non-PIN point-of-sale')
# (135, 'transactions.\tW hether \to r\tn ot\tyo u\tch oose\tt o\th ave\tyo ur\te veryday\td ebit\tc ard\tt')
# (136, 'ebit\tc ard\tt ransactions\tc overed\tw ill\tn ot\ta ffect\tt he\tw ay\tw e\tt reat\tyo ur\tr ecurring\td ebit\tc')
# (137, 'ecurring\td ebit\tc ard\tt ransactions\t( such\ta s\tm onthly\tm ovie\tr entals,\tg ym\tm emberships\to r\ts')
# (138, 'emberships\to r\ts ubscriptions)')
# (139, 'when\tyou\tdon’t\thave\tenough\tmoney\tin\tyour\taccount\tto\tcover\tthe\ttransactions.\tWe\tmay,\tat\tour\tdiscreti')
# (140, 'may,\tat\tour\tdiscretion,\tauthorize\tand\tpay\ta\trecurring\tdebit\tcard\ttransaction\tthat\tcauses\tan\toverdraf')
# (141, 't\tcauses\tan\toverdraft\tand\tcharge\tan\tOverdraft\tFee.')
# (142, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (143, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (144, 'CHASE TOTAL CHECKING\n®\n3\nHOW  \nDE\nPOSITS AND \nWITHDRAWALS \nWORK\nThe Order in \nWh\nich Withdrawals')
# (145, 'Wh\nich Withdrawals \nan\nd Deposits \nAr\ne Posted During \nOur Nightly \nProcessing')
# (146, 'Processing\nPosting order is the order in which we apply deposits and withdrawals to your')
# (147, 'account. We provide you with visibility into how transactions are posted and in')
# (148, 'what order to help you better manage your account.')
# (149, 'When we transition from one business day to the next business day we post')
# (150, 'transactions to and from your account during our nightly processing. The')
# (151, 'order in which we generally post transactions during nightly processing for \neach business day is:')
# (152, '•  First, we make any previous day adjustments, and add deposits to your\naccount.')
# (153, 'account.\n•  Second, we subtract transactions in chronological order by using the date')
# (154, 'and time of when the transaction was authorized or shown as pending.')
# (155, 'This includes ATM and Chase banker withdrawals, transfers and payments;')
# (156, 'automatic payments; chase.com or Chase Mobile online transactions; checks')
# (157, 'drawn on your account; debit card transactions; wire transfers; and real time')
# (158, 'payments. If multiple transactions have the same date and time, then they')
# (159, 'are posted in high to low dollar order.')
# (160, '-  There are some instances where we do not have the time of the transaction')
# (161, 'therefore we post at the end of the day the transaction occurred:')
# (162, '• We are unable to show the transaction as pending; or')
# (163, '•  We don’t receive an authorization request from the merchant but the')
# (164, 'transaction is presented for payment.')
# (165, '•  Third, there are some transactions that we cannot process automatically or')
# (166, 'until we’ve completed posting of your chronological transactions. This includes')
# (167, 'Overdraft Protection transfers or transfers to maintain target balances in other')
# (168, 'accounts. We subtract these remaining transactions in high to low dollar order.')
# (169, '• Finally, fees are assessed last.')
# (170, 'If you review your account during the day, you will see that we show')
# (171, 'some transactions as “pending.” For details, refer to the section “Pending”')
# (172, 'transactions in the Deposit Account Agreement . These transactions impact')
# (173, 'your available balance, but have not yet posted to your account and do not')
# (174, 'guarantee that we will pay these transactions to your account if you have a')
# (175, 'negative balance at that time. We may still return a transaction unpaid if your')
# (176, 'balance has insufficient funds during that business day’s nightly processing,')
# (177, 'even if it had been displayed as a “pending” transaction on a positive balance')
# (178, 'during the day. If a transaction that you made or authorized does not display')
# (179, 'as “pending,” you are still responsible for it and it may still be posted against')
# (180, 'your account during nightly processing.\nWhen Your Deposits \nAre Available \n(S\nee Funds')
# (181, '(S\nee Funds \nAvailability Policy in \nthe Deposit Account \nAgreement for \ndetails)')
# (182, 'details)\n• Cash deposit – Same business day\n• Direct deposit/wire transfer – Same business day')
# (183, '• Check deposit – Usually the next business day, but sometimes longer:')
# (184, '-  If we place a longer hold on a check, the first $225 will be available by the\nnext business day')
# (185, 'next business day\n-  The date your deposit is expected to be available will be displayed on your')
# (186, 'receipt\n-  In some situations, we may notify you at the time or after your deposit is')
# (187, 'made that your funds (including the first $225) will not be available for up to\nseven business days')
# (188, 'seven business days\nA “business day” is a non-holiday weekday. The cutoff times listed in the')
# (189, 'section above will determine the “business day” for your deposit.\nOTHER ATM \nAN\nD DEBIT CARD \nFEES')
# (190, 'D DEBIT CARD \nFEES\nCard Replacement – Rush Request: You request express shipping of a')
# (191, 'replacement debit or ATM card \n(A\nvoid this fee by requesting standard shipping)\n$5 p')
# (192, '$5 p\ner card, upon request\nNon-ATM Cash: You use your Chase Debit Card to withdraw cash from')
# (193, 'another financial institution (excluding ATMs)\n3% o\nf the dollar amount of \nthe transaction OR')
# (194, '$5, w\nhichever is greater\nForeign Exchange Rate Adjustment: You make card purchases,  \nno')
# (195, 'no\nn-ATM cash transactions or ATM withdrawals in a currency other \nthan U.S. dollars')
# (196, 'than U.S. dollars\n3% o f withdrawal amount \nafter conversion to U.S. \ndollars. For additional')
# (197, 'information on foreign \nexchange rates, refer to the \nDeposit Account Agreement')
# (198, 'See the next page for other fees that may apply.')
# (199, 'CHASE TOTAL CHECKING\n®\n4\nWIRE TRANSFER \nFEES4, 5')
# (200, 'FEES4, 5\nDomestic and International Incoming Wire: A wire transfer is \ndeposited into your account')
# (201, '$15 per transfer OR  \n$0 i\nf the transfer was \noriginally sent with the help')
# (202, 'of a Chase banker or using \nchase.com or Chase Mobile')
# (203, 'Domestic Wire: A banker helps you to send a wire to a bank account \nwithin the U.S.$35')
# (204, 'within the U.S.$35 \nper transfer\nOnline Domestic Wire: You use chase.com or Chase Mobile to send a')
# (205, 'wire from your account to a bank account within the U.S. $25 per transfer')
# (206, 'Consumer USD/FX International Wire: A banker helps you send a wire')
# (207, 'to a bank account outside the U.S. in either U.S. dollars (USD) or foreign \ncurrency (FX)\n$50')
# (208, 'currency (FX)\n$50 \nper transfer\nConsumer Online USD International Wire:  You use chase.com or')
# (209, 'Chase Mobile to send a wire from your account to a bank account')
# (210, 'outside the U.S. in U.S. dollars (USD)\n$40 \nper transfer')
# (211, '$40 \nper transfer\nConsumer Online FX International Wire:  You use chase.com or Chase')
# (212, 'Mobile to send a wire from your account to a bank account outside the')
# (213, 'U.S. in foreign currency (FX)\n$5 per transfer OR  \n$0 p er transfer if the')
# (214, 'amount is equal to $5,000 \nUSD or more')
# (215, 'For wire transfers you send or we receive in a foreign currency, the exchange rate is determined by')
# (216, 'is determined by us in our sole discretion')
# (217, 'and includes a spread, which we may make a commission from when completing the foreign currency')
# (218, 'foreign currency exchange. You should')
# (219, 'expect that these foreign exchange rates will be less favorable than rates quoted online or in')
# (220, 'quoted online or in publications. For additional')
# (221, 'information on these rates, refer to the Deposit Account Agreement  and Wire Transfers Agreements.')
# (222, 'OTHER FEES\nStop Payment: You contact us and a banker places your stop payment')
# (223, 'request on a check or ACH$30 p er request')
# (224, 'Online or Automated Phone Stop Payment: You use chase.com , Chase')
# (225, 'Mobile or our automated phone system to place a stop payment on a')
# (226, 'check. Only some types of stop payments are available\n$25 p\ner request')
# (227, '$25 p\ner request\nOrder for Checks or Supplies: An order of personal checks, deposit')
# (228, 'slips or other banking supplies\nVaries (based on items \nordered)')
# (229, 'ordered)\nCounter Check: A blank page of 3 personal checks we print upon your')
# (230, 'request at a branch$3 per page\nMoney Order: A check issued by you, purchased at a branch, for an')
# (231, 'amount up to $1,000$5 p\ner check')
# (232, 'er check\nCashier’s Check: A check issued by the bank, purchased at a branch,')
# (233, 'for any amount and to a payee you designate$10 per check')
# (234, 'Legal Processing: Processing of any garnishment, tax levy, or other')
# (235, 'court administrative order against your accounts, whether or not the \nfunds are actually paid')
# (236, 'Up to $100 per order\nSAFE DEPOSIT BOX \nANNUAL RENT')
# (237, 'ANNUAL RENT\nAssessed annually at lease renewal. We currently do not rent new Safe \nDeposit Boxes')
# (238, 'Deposit Boxes\nVaries by size and location, \nincludes sales tax where')
# (239, 'applicable (disclosed on your \nannual invoice)')
# (240, '4\t \tFinancial\tinstitutions\tmay\tdedu ct\tpro cessing\tfee s\tand/ or\tcharg es\tfro m\tthe\tamou')
# (241, 'es\tfro m\tthe\tamou nt\tof\tthe\tinco ming\tor\tout going\twire\ttran sfers,\tinclu ding\ton\tretu')
# (242, 'ding\ton\tretu rned\twire\ttran sfers.\tAny\tdedu ctions\ttake n\tby\tus,\tand\tour\taffili ates,\tmay\tinclu de')
# (243, 'processing fees charged by Chase.')
# (244, '5\t \tWe\tmay\tuse\tan y\tfu nds\ttr ansfer\tsy stem\twe\tbe lieve\tre asonable\tto\tco mplete\tyo ur\tre')
# (245, 'mplete\tyo ur\tre quest,\tre gardless\tof\tan y\tin structions\tyo u\tmi ght\tgi ve\tus .\tIf\twe\tal so\tar e\tth')
# (246, 'so\tar e\tth e\tre cipient’s\tba nk,\twe\tma y\tco mplete\tyo ur\tre quest\tus ing\tan\tin ternal')
# (247, 'transfer, and assess a wire transfer fee.')
# (248, 'HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (249, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (250, 'JPMorgan Chase Bank, N.A. Member FDIC\n© 2024 JPMorgan Chase & Co.\nEffective 11/17/2024')
# (251, 'FEETABLE-TOTAL-1124-ONLN')
