# %%
from agents import Agent,Runner
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
agent=Agent( name="simple-agent",
 
 instructions="You are a helpful assistant that provides concise answers to user queries.",           
)

# %%
response= await Runner.run(agent,"How to learn Agentic AI?")

# %%
print(response)
# Out:
# RunResult:
# - Last agent: Agent(name="simple-agent", ...)
# - Final output (str):
#     To learn about Agentic AI (AI systems capable of autonomous decision-making and goal pursuit), you can follow these steps:
#
#     1. **Understand the Basics**
#        - Learn AI fundamentals: machine learning, reinforcement learning, and basics of artificial intelligence.
#        - Resources: [Coursera’s AI for Everyone](https://www.coursera.org/learn/ai-for-everyone), [DeepLearning.AI](https://www.deeplearning.ai/).
#
#     2. **Study Agentic AI Concepts**
#        - Read introductory articles and papers on agency in AI ([ARC Eliciting Latent Knowledge](https://www.alignmentforum.org/posts/ZqDNXgq8oF4rbdsbQ/an-overview-of-agency-in-ai)).
#        - Understand related topics: autonomous agents, goal-setting, and reasoning.
#
#     3. **Hands-on Experience**
#        - Explore frameworks like OpenAI Gym, or LangChain for agent-based models.
#        - Build your own simple agents using Python. Tutorials: [OpenAI Gym Tutorial](https://www.gymlibrary.dev/), [LangChain Agents](https://python.langchain.com/docs/modules/agents/).
#
#     4. **Learn from Research**
#        - Read research papers on agentic AI from venues like arXiv, NeurIPS, or blogs such as [LessWrong](https://www.lesswrong.com/) or [Alignment Forum](https://www.alignmentforum.org/).
#        - Follow AI alignment discussions, as agency is a core concern ([AI Alignment Newsletter](https://www.alignmentforum.org/ai-alignment-newsletter)).
#
#     5. **Projects & Community**
#        - Contribute to open-source projects (e.g., RLlib, PettingZoo).
#        - Join communities: [Discord AI groups](https://discord.gg/machinelearning), [AI Alignment Slack](https://aisafety.community/).
#
#     **Tips:**
#     - Start simple—build small agents before exploring complex environments.
#     - Stay updated as the field evolves quickly.
#     - Engage in discussions and ask questions on forums like Reddit’s r/MachineLearning.
#
#     Would you like beginner projects or more reading recommendations?
# - 1 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)
